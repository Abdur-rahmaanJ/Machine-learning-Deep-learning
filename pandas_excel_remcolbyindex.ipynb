# %% [markdown]
# prepared for pythonmembers.club

# %% [markdown]
# # removing last columns of excel dataframe using pandas by index

# %% [markdown]
# here is our last code

# %%
import pandas as pd
excel = pd.ExcelFile('C:/Users/Dell/Downloads/us_data.xls')
df = excel.parse(excel.sheet_names[0])
df2 = excel.parse(skiprows=3)
df3 = df2[:-21] # just a basic slicing

# %%
df3
# Out:
#      Year  Population1 Violent\ncrime Violent \ncrime \nrate   \
# 0    1994  260327021.0        1857670                   713.6
# 1    1995  262803276.0        1798792                   684.5
# 2    1996  265228572.0        1688540                   636.6
# 3    1997  267783607.0        1636096                     611
# 4    1998  270248003.0        1533887                   567.6
# 5    1999  272690813.0        1426044                     523
# 6    2000  281421906.0        1425486                   506.5
# 7   20013  285317559.0        1439480                   504.5
# 8    2002  287973924.0        1423677                   494.4
# 9    2003  290788976.0        1383676                   475.8
# 10   2004  293656842.0        1360088                   463.2
# 11   2005  296507061.0        1390745                     469
# 12   2006  299398484.0        1435123                   479.3
# 13   2007  301621157.0        1422970                   471.8
# ...

# %% [markdown]
# though we did it in our last tutorial, just one step to understand how to remove by index

# %% [markdown]
# to get all columns we do

# %%
df3.columns
# Out:
# Index(['Year', 'Population1', 'Violent\ncrime', 'Violent \ncrime \nrate ',
#        'Murder and\nnonnegligent \nmanslaughter',
#        'Murder and \nnonnegligent \nmanslaughter \nrate ',
#        'Rape\n(legacy\ndefinition)2', 'Rape\n(legacy\ndefinition)2\nrate',
#        'Robbery', 'Robbery \nrate ', 'Aggravated \nassault',
#        'Aggravated \nassault rate ', 'Property \ncrime',
#        'Property \ncrime \nrate ', 'Burglary', 'Burglary \nrate ',
#        'Larceny-\ntheft', 'Larceny-\ntheft rate ', 'Motor \nvehicle \ntheft',
#        'Motor \nvehicle \ntheft \nrate ', 'Unnamed: 20', ' ', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# we can see clearly that our 4 last columns are unneeded

# %%
df3.columns[-4:]
# Out:
# Index(['Unnamed: 20', ' ', 'Unnamed: 22', 'Unnamed: 23'], dtype='object')

# %%
df3.columns[:-4]
# Out:
# Index(['Year', 'Population1', 'Violent\ncrime', 'Violent \ncrime \nrate ',
#        'Murder and\nnonnegligent \nmanslaughter',
#        'Murder and \nnonnegligent \nmanslaughter \nrate ',
#        'Rape\n(legacy\ndefinition)2', 'Rape\n(legacy\ndefinition)2\nrate',
#        'Robbery', 'Robbery \nrate ', 'Aggravated \nassault',
#        'Aggravated \nassault rate ', 'Property \ncrime',
#        'Property \ncrime \nrate ', 'Burglary', 'Burglary \nrate ',
#        'Larceny-\ntheft', 'Larceny-\ntheft rate ', 'Motor \nvehicle \ntheft',
#        'Motor \nvehicle \ntheft \nrate '],
#       dtype='object')

# %% [markdown]
# now delete

# %%
# deleting last 4 rows
df4 = df3.drop(df3.columns[-4:],axis=1)
df4
# Out:
#      Year  Population1 Violent\ncrime Violent \ncrime \nrate   \
# 0    1994  260327021.0        1857670                   713.6
# 1    1995  262803276.0        1798792                   684.5
# 2    1996  265228572.0        1688540                   636.6
# 3    1997  267783607.0        1636096                     611
# 4    1998  270248003.0        1533887                   567.6
# 5    1999  272690813.0        1426044                     523
# 6    2000  281421906.0        1425486                   506.5
# 7   20013  285317559.0        1439480                   504.5
# 8    2002  287973924.0        1423677                   494.4
# 9    2003  290788976.0        1383676                   475.8
# 10   2004  293656842.0        1360088                   463.2
# 11   2005  296507061.0        1390745                     469
# 12   2006  299398484.0        1435123                   479.3
# 13   2007  301621157.0        1422970                   471.8
# ...
